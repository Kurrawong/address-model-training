# %% [markdown]
# ![](img/KurrawongAI_350.png)
#
# # Address Model Training - Module 1
#
# ## Introduction, Overview & Concepts
#
# This training module first provides an introduction to the [ICSM ANZ Address Model](https://linked.data.gov.au/def/addr), referred to hereafter as just the 'Address Model', and overviews its purpose, development and links to other models. It them provides an overview of its content - how it works and what it depends on, with examples. Finally, it provides a bit more depth on background addressing and technical model concepts. This last part won't be necessary for those just wanting a general overview of the Address Model.

# %% [markdown]
# ## 1. Introduction
#
# A general overview of the Address Model, its purpose, development and links to other models.

# %% [markdown]
# ## 2. Overview
#
# A general overview of the Address Model content - how it works and what it depends on.

# %% [markdown]
# ## 3. Concepts
#
# More depth on background addressing and technical model concepts.

# %%
x = 1 + 1
x += 1
print(x)
# Out:
# 3
