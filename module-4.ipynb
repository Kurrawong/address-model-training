# %% [markdown]
# ![](module-1/img/KurrawongAI_350.png)
#
# # Address Model Training - Module 4, Practice

# %% [markdown]
# ## 1. Completing Module 3

# %% [markdown]
# ### 3.1. Vocab editing
#
# _Section **2.3 Vocabulary Extension** from Module 2 that we didn't get through._
#
# ### 3.2. Profiling
#
# _Section **2.4 Profiling** from Module 2 that we didn't get through._
